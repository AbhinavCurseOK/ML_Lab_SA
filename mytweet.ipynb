# %% [markdown]
# <a href="https://colab.research.google.com/github/AbhinavCurseOK/ML_Lab_SA/blob/main/mytweet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install tweepy

# %%
import tweepy
consumer_key = '#'
consumer_secret = '#'
bearer_token = '##'
client = tweepy.Client(bearer_token=bearer_token)

# %%
import pandas as pd
import os

# %%
response = client.search_recent_tweets(query='Blockchain Security', max_results=10)
if response.data:
    tweets_list = [tweet.text for tweet in response.data]
    new_tweets_df = pd.DataFrame(tweets_list, columns=['Tweet'])

    file_path = 'tweets.csv'
    if os.path.exists(file_path):
        new_tweets_df.to_csv(file_path, mode='a', header=False, index=False)
    else:
        new_tweets_df.to_csv(file_path, index=False)

    print("Tweets saved to 'tweets.csv'.")
else:
    print("No tweets found.")
# Out:
# Tweets saved to 'tweets.csv'.

# %%
df = pd.read_csv('tweets.csv',header=None)
df.columns = ['Tweet']
#df = df.drop(index=0)
#df.to_csv('tweets.csv', index=False)
df
# Out:
#                                                  Tweet
# 0                                                Tweet
# 1    RT @ShibArmy_2025: 🌟 $CRA The Crypto Revolutio...
# 2    Crypto meme series:\nNew Year's resolution\n#C...
# 3    Polygon blockchain is a reliable , fast and se...
# 4    📊 $XDC Price Update: $0.073\n\nAmidst market w...
# ..                                                 ...
# 176  RT @ElectraProtocol: Electra Protocol uses UTX...
# 177  Orochi is excited to announce a strategic part...
# 178  RT @PortaltoBitcoin: Portal to Bitcoin is exci...
# 179  RT @SolvexNetwork: 🌟 SolveX: The Blockchain Pl...
# 180  RT @an99jokeridi: It benefit include \n\nEffor...
#
# [181 rows x 1 columns]

# %%
df.shape
# Out:
# (181, 1)

# %%
#### in free tier from one email id only 100 tweets can be extracted from twitter(in one month,),each 10 tweets take around 15 minutes
